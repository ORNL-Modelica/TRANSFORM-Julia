# %%
include("../../../HeatAndMassTransfer/Examples/resistanceCheck.jl")
# Out:
# Q_total: Sphere Model
# var	time	value
# min	1.0	-2510.0 ± 500.0
# max	0.0	0.0 ± 0.0
#
# Measured	Predicted	M-P		(M-P)/M
# -2.51e+03	-2.51e+03	-2.20e-03	8.75e-07
#
# Q_total: Convection Model
# var	time	value
# min	1.0	-599.9999999999998
# max	0.0	0.0
#
# Measured	Predicted	M-P		(M-P)/M
# -6.00e+02	-6.00e+02	-2.27e-13	3.79e-16
#
# Q_total: Contact Model
# var	time	value
# min	1.0	-7.999999999999998
# max	0.0	0.0
#
# Measured	Predicted	M-P		(M-P)/M
# -8.00e+00	-8.00e+00	-1.78e-15	2.22e-16
#
# Q_total: Radiation Model
# var	time	value
# min	1.0	-126.51637977650799
# max	0.0	0.0
#
# Measured	Predicted	M-P		(M-P)/M
# -1.27e+02	-1.27e+02	-2.23e-07	1.77e-09
